# %% [markdown]
# <a href="https://colab.research.google.com/github/eyoung-15/IAT460_DJPal_Final_Project/blob/main/DJ_Pal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q gradio librosa soundfile pydub numpy numba llvmlite
# !pip install -q torch>=2.4 torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q git+https://github.com/facebookresearch/demucs
# !pip install -q git+https://github.com/huggingface/transformers.git
# !apt-get -qq install ffmpeg
